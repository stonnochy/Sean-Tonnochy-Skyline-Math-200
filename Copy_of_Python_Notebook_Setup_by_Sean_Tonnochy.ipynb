# %% [markdown]
# <a href="https://colab.research.google.com/github/stonnochy/Sean-Tonnochy-Skyline-Math-200/blob/main/Copy_of_Python_Notebook_Setup_by_Sean_Tonnochy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Research Question # 1 : Does having close friends correlate to how optimistic you are about your future?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url='https://drive.google.com/file/d/1IbHzUMYKFBkmW3TIvryP7XJlW-WkmGEw/view?usp=sharing'
path= 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
df = pd.read_csv(path)
df.head()
# Out:
#        AID  BIO_SEX        agew1 IMONTH4 IDAY4 IYEAR4   MACNO4 INTID4  \
# 0  5710027        2
# 1  5710131        2  19.42739726       5     6   2008  2288160    160
# 2  5710317        1
# 3  5710386        1  20.43013699       5    22   2008  2288238    238
# 4  5710455        2
#
#   BIO_SEX4 VERSION4  ... H4EO5C H4EO5D H4EO5E H4EO5F H4EO5G H4EO5H H4EO5I  \
# 0                    ...
# 1        2     V5.4  ...      0      0      0      0      0      0      0
# 2                    ...
# 3        1     V5.4  ...      0      0      0      0      0      0      0
# 4                    ...
#
#   H4EO5J H4EO6 H4EO7
# 0
# 1      0     2     1
# 2
# 3      0     4     1
# 4
#
# [5 rows x 976 columns]

# %% [markdown]
# Codebook 1

# %% [markdown]
# Weathersby, it won't let me put a picture here

# %%
#Manage data for variable 1
df['close_friends'] = df['H4WS4']

# %%
df['close_friends'].value_counts()
# Out:
# 3     2319
#       1390
# 2     1121
# 4      861
# 5      620
# 1      145
# 95      46
# 96       1
# 98       1
# Name: close_friends, dtype: int64

# %%
df['close_friends'] = df['close_friends'].loc[ df['close_friends'] !=' ']
df['close_friends'] = df['close_friends'].loc[ df['close_friends'] !='98']
df['close_friends'] = df['close_friends'].loc[ df['close_friends'] !='96']
df['close_friends'] = df['close_friends'].loc[ df['close_friends'] !='95']
df['close_friends'].value_counts()
# Out:
# 3    2319
# 2    1121
# 4     861
# 5     620
# 1     145
# Name: close_friends, dtype: int64

# %%
df['close_friends'].replace(['1','2','3','4','5'] , ['NONE ', '1-2', '3-5','6-9','10+'], inplace = True)
df['close_friends'].value_counts()
# Out:
# 3-5      2319
# 1-2      1121
# 6-9       861
# 10+       620
# NONE      145
# Name: close_friends, dtype: int64

# %%
#Graphs and tables or statistics

# %%
#Pie chart
explode = (0.0,0.0,0.0,0.4)
plt.title("How many close friends do I have?")
df['close_friends'].value_counts().plot(kind ='pie', autopct='%1.1f%%', colors=['maroon', 'lavender', 'gray', 'saddlebrown', 'olivedrab'])
plt.legend(loc ="upper right")

# %%
#Bar chart
df['close_friends'].value_counts().plot(kind ='bar')
# Out:
# <Axes: >

# %%
#Basic Statistical Measure
df['close_friends'].replace(['1','2','3','4','5'] , ['NONE', '1-2', '3-5','6-9','10+'], inplace = True)
df['close_friends'].value_counts()
# Out:
# 3-5      2319
# 1-2      1121
# 6-9       861
# 10+       620
# NONE      145
# Name: close_friends, dtype: int64

# %% [markdown]
# Codebook 2:

# %% [markdown]
# Weathersby, it won't let me put a picture here

# %%
#Manage data for variable 1

# %%
df['optimistic'] = df['H4PE7']

# %%
df['optimistic'].value_counts()
# Out:
# 2    2677
#      1391
# 3    1046
# 1     941
# 4     392
# 5      46
# 8       6
# 6       5
# Name: optimistic, dtype: int64

# %%
df['optimistic'] = df['optimistic'].loc[ df['optimistic'] !=' ']
df['optimistic'] = df['optimistic'].loc[ df['optimistic'] !='6']
df['optimistic'] = df['optimistic'].loc[ df['optimistic'] !='8']
df['optimistic'].value_counts()
# Out:
# 2    2677
# 3    1046
# 1     941
# 4     392
# 5      46
# Name: optimistic, dtype: int64

# %%
df['optimistic'].replace(['1','2','3','4','5'] , ['STRONGLY AGREE', 'AGREE', 'NEITHER AGREE NOR DISAGREE','DISAGREE','STRONGLY DISAGREE'], inplace = True)
df['optimistic'].value_counts()
# Out:
# AGREE                         2677
# NEITHER AGREE NOR DISAGREE    1046
# STRONGLY AGREE                 941
# DISAGREE                       392
# STRONGLY DISAGREE               46
# Name: optimistic, dtype: int64

# %%
#Graphs and tables or statistics

# %%
#Pie chart
explode = (0.0,0.0,0.0,0.4)
plt.title("I'm optimistic about my future.")
df['optimistic'].value_counts().plot(kind ='pie', autopct='%1.1f%%', colors=['olivedrab', 'rosybrown', 'gray', 'saddlebrown'])
plt.legend(loc ="upper right")

# %%
#Bar chart
df['optimistic'].value_counts().plot(kind ='bar')
# Out:
# <Axes: >

# %%
#Basic Statistical Measure
df['optimistic'].replace(['1','2','3','4','5'] , ['STRONGLY AGREE', 'AGREE', 'NEITHER AGREE NOR DISAGREE','DISAGREE','STRONGLY DISAGREE'], inplace = True)
df['optimistic'].value_counts()
# Out:
# AGREE                         2677
# NEITHER AGREE NOR DISAGREE    1046
# STRONGLY AGREE                 941
# DISAGREE                       392
# STRONGLY DISAGREE               46
# Name: optimistic, dtype: int64

# %% [markdown]
# Research Question # 2 : Does having siblings reflect how you react to things that already happened to you?

# %% [markdown]
# Codebook 1

# %% [markdown]
# It wont let me put a picture, I will ask for help in class

# %%
#Manage data for variable 1

# %%
df['dont_worry'] = df['H4PE30']

# %%
df['dont_worry'].value_counts()
# Out:
# 4    1972
# 2    1495
#      1391
# 3    1097
# 1     274
# 5     265
# 6       5
# 8       5
# Name: dont_worry, dtype: int64

# %%
df['dont_worry'] = df['dont_worry'].loc[ df['dont_worry'] !=' ']
df['dont_worry'] = df['dont_worry'].loc[ df['dont_worry'] !='6']
df['dont_worry'] = df['dont_worry'].loc[ df['dont_worry'] !='8']
df['dont_worry'].value_counts()
# Out:
# 4    1972
# 2    1495
# 3    1097
# 1     274
# 5     265
# Name: dont_worry, dtype: int64

# %%
df['dont_worry'].replace(['1','2','3','4','5'] , ['STRONGLY AGREE', 'AGREE', 'NEITHER AGREE NOR DISAGREE','DISAGREE','STRONGLY DISAGREE'], inplace = True)
df['dont_worry'].value_counts()
# Out:
# DISAGREE                      1972
# AGREE                         1495
# NEITHER AGREE NOR DISAGREE    1097
# STRONGLY AGREE                 274
# STRONGLY DISAGREE              265
# Name: dont_worry, dtype: int64

# %%
#Graphs and tables or statistics

# %%
#Pie chart
explode = (0.0,0.0,0.0,0.4)
plt.title("I don't worry about things that have already happened.")
df['dont_worry'].value_counts().plot(kind ='pie', autopct='%1.1f%%', colors=['olivedrab', 'rosybrown', 'gray', 'saddlebrown','pink'])
plt.legend(loc ="upper right")

# %%
#Bar chart
df['dont_worry'].value_counts().plot(kind ='bar')
# Out:
# <Axes: >

# %%
#Basic Statistical Measure
df['dont_worry'].replace(['1','2','3','4','5'] , ['STRONGLY AGREE', 'AGREE', 'NEITHER AGREE NOR DISAGREE','DISAGREE','STRONGLY DISAGREE'], inplace = True)
df['dont_worry'].value_counts()
# Out:
# DISAGREE                      1972
# AGREE                         1495
# NEITHER AGREE NOR DISAGREE    1097
# STRONGLY AGREE                 274
# STRONGLY DISAGREE              265
# Name: dont_worry, dtype: int64

# %% [markdown]
# Codebook 2

# %%
#Manage data for variable 1

# %%
df['siblings'] = df['H4WS1']

# %%
df['siblings'] = df['siblings'].loc[df['siblings'] != ' ']

# %%
df['siblings'] =pd.to_numeric(df['siblings'],errors = 'coerce')

# %%
df['siblings'] = df['siblings'].loc[ df['siblings'] !='6']
df['siblings'] = df['siblings'].loc[ df['siblings'] !=' ']
df['siblings'] = df['siblings'].loc[ df['siblings'] < 5]
df['siblings'].value_counts()
# Out:
# 1.0    1342
# 2.0    1265
# 3.0     813
# 4.0     539
# 0.0     242
# Name: siblings, dtype: int64

# %%
df['siblings'].replace(['0','1','2','3','4'] , ['NONE','1 ', '2', '3','4',], inplace = True)
df['siblings'].value_counts()
# Out:
# 1.0    1342
# 2.0    1265
# 3.0     813
# 4.0     539
# 0.0     242
# Name: siblings, dtype: int64

# %%
#Graphs and tables or statistics

# %%
explode = (0,1,2,3,4)
plt.title("How many siblings do you have?")
df['siblings'].value_counts().plot(kind ='pie', autopct='%1.1f%%', colors=['olivedrab', 'rosybrown', 'gray', 'saddlebrown'])
plt.legend(loc ="upper right")

# %%
plt.xlabel("Amount of Siblings")
plt.ylabel("Percent")
plt.title("How many siblings do you have?")
df['siblings'].value_counts(normalize = True).plot(kind ='bar', color = 'blue', width = 0.6, alpha = 0.5)
# Out:
# <Axes: title={'center': 'How many siblings do you have?'}, xlabel='Amount of Siblings', ylabel='Percent'>

# %%
plt.xlabel("Amount of Siblings")
plt.ylabel("Percent")
plt.title("How many siblings do you have?")
sns.histplot(x='siblings', data=df  , bins= 5, color='green')
# Out:
# <Axes: title={'center': 'How many siblings do you have?'}, xlabel='Amount of Siblings', ylabel='Percent'>

# %%
plt.xlabel("Amount of Siblings")
plt.ylabel("Percent")
plt.title("How many siblings do you have?")
sns.boxplot(x = 'siblings', data = df)
# Out:
# <Axes: title={'center': 'How many siblings do you have?'}, xlabel='siblings', ylabel='Percent'>
